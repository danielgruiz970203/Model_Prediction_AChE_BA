# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../output_docking_AChE/DockingResults-2_data.mvdresults", sep = "\t")
df.columns

No_poses = 3

# %%
df["PoseEnergy"]
value , count = np.unique(df["SMILES"], return_counts = True)
conta = 0
for idx, i in enumerate(count):
    if i == 1:
        
        df = df.append(pd.DataFrame(df.iloc[list(df['SMILES']).index(value[idx]),:]).T)
        df = df.append(pd.DataFrame(df.iloc[list(df['SMILES']).index(value[idx]),:]).T)
    elif i == 2:
        df = df.append(pd.DataFrame(df.iloc[list(df['SMILES']).index(value[idx]),:]).T)
    else:
        pass

# %%
value , count = np.unique(df["SMILES"], return_counts = True)
count
len(df)
# Out:
# 7638

# %%
df_ = pd.DataFrame()
for i in range(0,len(list(df.loc[:,"PoseEnergy"])),No_poses):
    
    if list(df.loc[:,"PoseEnergy"])[i] <= list(df.loc[:,"PoseEnergy"])[i+1] and list(df.loc[:,"PoseEnergy"])[i] <= list(df.loc[:,"PoseEnergy"])[i+2]:
               
        df_ = df_.append(pd.DataFrame(df.iloc[i,:]).T)
        
    elif list(df.loc[:,"PoseEnergy"])[i+1] <= list(df.loc[:,"PoseEnergy"])[i+2]:
        
        df_ = df_.append(pd.DataFrame(df.iloc[i+1,:]).T)
        
    else:
        #if i+2 == 6968:
         
         #   df_ = df_.append(pd.DataFrame(df.iloc[i+1,:]).T)
        
       # else:
        
        df_ = df_.append(pd.DataFrame(df.iloc[i+2,:]).T)

df_.to_csv("./Filter_file_docking_output.tsv", sep = "\t")

# %%
df_
# Out:
#      C0 CO2minus Cofactor (VdW) Cofactor (elec) Cofactor (hbond) Csp2 Csp3  \
# 0     1        0              0               0                0    9    4
# 3     1        0              0               0                0   14    9
# 6     1        0              0               0                0   15   13
# 9     1        0              0               0                0   14    8
# 12    1        0              0               0                0   14   11
# ...  ..      ...            ...             ...              ...  ...  ...
# 5336  1        0              0               0                0   24    9
# 4124  1        0              0               0                0   18   11
# 6921  1        0              0               0                0   10   11
# 4060  1        0              0               0                0   28   10
# 6988  1        0              0               0                0    6   15
#
#      DOF E-Inter (cofactor - ligand) E-Inter (protein - ligand)  ... RMSD  \
# 0      0                           0                   -102.254  ...    0
# 3      9                           0                   -180.878  ...    0
# 6     13                           0                    -198.64  ...    0
# 9      8                           0                   -169.882  ...    0
# 12    11                           0                   -187.225  ...    0
# ...   ..                         ...                        ...  ...  ...
# 5336   2                           0                   -158.096  ...    0
# 4124   5                           0                   -168.594  ...    0
# 6921   3                           0                   -159.608  ...    0
# 4060   2                           0                   -200.229  ...    0
# 6988   2                           0                   -165.728  ...    0
#
#      RerankScore Run SimilarityScore   Steric Torsions VdW (LJ12-6) carbonyl  \
# 0       -70.9368   0               0  -97.974        0     -22.2062        0
# 3       -122.531   0               0 -176.829        9     -28.7617        1
# 6       -78.0669   0               0 -195.451       13      54.6899        1
# 9       -120.866   0               0 -166.785        8     -56.3723        1
# 12      -116.564   0               0 -185.922       11     -26.8101        1
# ...          ...  ..             ...      ...      ...          ...      ...
# 5336    -36.1441   0               0 -158.096        2      83.9626        2
# 4124     -9.6729   0               0 -163.178        5      176.217        2
# 6921    -116.013   0               0 -157.303        3     -47.1635        1
# 4060    -1.02141   0               0 -200.229        2      170.047        2
# 6988    -121.289   0               0 -163.446        2     -30.2162        2
#
#      halogen                                             SMILES
# 0          0                        NC1=C2CCCCC2=NC=3C1=CC=CC=3
# 3          0  O=C(C1=CN=C(NN)C=C1)NCCCCCNC2=C3CCCCC3=NC4=CC=...
# 6          0  O=C(C1=CC=C(NN)C=C1)NCCCCCCCCCNC2=C3CCCCC3=NC4...
# 9          0  O=C(C1=CN=C(NN)C=C1)NCCCCNC2=C3CCCCC3=NC4=CC=C...
# 12         0  O=C(C1=CN=C(NN)C=C1)NCCCCCCCNC2=C3CCCCC3=NC4=C...
# ...      ...                                                ...
# 5336       2  ClC(=CC=1)C=CC=1C2C3CSCN3C6(C5=CC=CC4=CC=CC(C6...
# 4124       1  ClC(C=C1)=CC2=C1NC(=O)C32N4CSCC4C(C5=CC=C(OC)C...
# 6921       0  O=C(OC)C1C2CC3C=4N(C)C5=CC=C(OC)C=C5C=4CC1N3CC...
# 4060       0  O=C1C2=CC=CC=C2C3(O)C41N5CCCC5C(C=6C=CC=C7C=6(...
# 6988       0  OC=1C(OC)=CC=C2C=1N(C(=O)CC)C3CCC45CC(=O)OC46C...
#
# [2546 rows x 51 columns]
